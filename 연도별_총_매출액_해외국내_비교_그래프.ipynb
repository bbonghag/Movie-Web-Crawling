# %%
import pandas as pd
import numpy as np

# %%
movie = pd.read_excel('연도별 상위50개 월,장르,코드,매출액 합본.xlsx')
movie
# Out:
#      연도_x  순위               영화명        개봉일          매출액  매출액 점유율      관객수  \
# 0    2004   1          태극기 휘날리며 2004-02-05  15687180500      3.6  2544911
# 1    2004   2               트로이 2004-05-21  12777346000      2.9  2001293
# 2    2004   3       내 머리 속의 지우개 2004-11-05  11919939500      2.7  1885827
# 3    2004   4            귀신이 산다 2004-09-17  11898748500      2.7  1875936
# 4    2004   5              투모로우 2004-06-03  11658584500      2.6  1830767
# ..    ...  ..               ...        ...          ...      ...      ...
# 945  2022  46                피그 2022-02-23    106682970      0.1    11611
# 946  2022  47  하늘의 푸르름을 아는 사람이여 2022-03-16    103052300      0.1    11508
# 947  2022  48    해리 포터와 불사조 기사단 2007-07-11    111181470      0.1    11478
# 948  2022  49       엔칸토: 마법의 세계 2021-11-24    101133120      0.1    11163
# 949  2022  50              메리 미 2022-03-16     76919800      0.1    10601
#
#     스크린수   상영횟수        코드                장르     러닝타임 제작국가  월별
# ...

# %%
# 3~5 봄
# 6~8 여름
# 9~11 가을 
# 12~2 겨울 
# 각 영화의 월별에 해당하는 계절을 추가하고 싶다 
movie

# %%
import pandas as pd
import numpy as np

list_of_dates = ['2019-11-20', '2020-01-02', '2020-02-05','2020-03-10','2020-04-16','2020-05-01']
employees = ['Hisila', 'Shristi','Zeppy','Alina','Jerry','Kevin']
salary = [200,400,300,500,600,300]
df = pd.DataFrame({"Name":employees,'Joined date': pd.to_datetime(list_of_dates),"Salary":salary})


def set_values(row, value):
    return value[row]
   
map_dictionary ={200 : "Low", 300 :"LOW", 400 : "MID",500:"HIGH",600:"HIGH"} 
   
df['Salary_Range'] = df['Salary'].apply(set_values, args =(map_dictionary, )) 

print(df)
# Out:
#       Name Joined date  Salary Salary_Range
# 0   Hisila  2019-11-20     200          Low
# 1  Shristi  2020-01-02     400          MID
# 2    Zeppy  2020-02-05     300          LOW
# 3    Alina  2020-03-10     500         HIGH
# 4    Jerry  2020-04-16     600         HIGH
# 5    Kevin  2020-05-01     300          LOW

# %%
# 한국,외국 이진분류 
# 한국 = 한국
# 한국 + @ = 한국 
# 외국 + @ = 외국 

def set_values(x,value):
  return value[x]

dic = {'한국':'한국', '미국':'외국', '미국,영국':'외국', '중국':'외국', '영국':'외국', '일본':'외국', '한국,중국':'한국', '한국,네덜란드,홍콩':'한국',
       '프랑스':'외국', '한국,태국':'한국', '중국,한국,홍콩':'한국', '한국,중국,몽고':'한국', '한국,미국,호주':'한국', '미국,독일':'외국', '영국,미국':'외국',
       '인도':'외국', '미국,뉴질랜드':'외국', '한국,홍콩,일본,태국':'한국', '한국,미국,중국':'한국', '독일,미국,영국':'외국','한국,미국':'한국', '한국,일본,중국':'한국',
       '한국,미국,홍콩':'한국', '영국,호주':'외국', '한국,홍콩':'한국', '벨기에':'외국', '미국,캐나다':'외국', '한국,필리핀':'한국', '한국,체코':'한국', '한국,독일':'한국',
       '미국,호주':'외국', '미국,프랑스':'외국', '미국,영국,스페인':'외국', '미국,벨기에,영국':'외국', '미국,일본,프랑스,캐나다':'외국', '미국,호주,뉴질랜드':'외국', '기타':'외국',
       '대만':'외국'}

movie['제작국가구분'] = movie['제작국가'].apply(set_values, args=(dic,))

# %%
movie
# Out:
#      연도_x  순위               영화명        개봉일          매출액  매출액 점유율      관객수  \
# 0    2004   1          태극기 휘날리며 2004-02-05  15687180500      3.6  2544911
# 1    2004   2               트로이 2004-05-21  12777346000      2.9  2001293
# 2    2004   3       내 머리 속의 지우개 2004-11-05  11919939500      2.7  1885827
# 3    2004   4            귀신이 산다 2004-09-17  11898748500      2.7  1875936
# 4    2004   5              투모로우 2004-06-03  11658584500      2.6  1830767
# ..    ...  ..               ...        ...          ...      ...      ...
# 945  2022  46                피그 2022-02-23    106682970      0.1    11611
# 946  2022  47  하늘의 푸르름을 아는 사람이여 2022-03-16    103052300      0.1    11508
# 947  2022  48    해리 포터와 불사조 기사단 2007-07-11    111181470      0.1    11478
# 948  2022  49       엔칸토: 마법의 세계 2021-11-24    101133120      0.1    11163
# 949  2022  50              메리 미 2022-03-16     76919800      0.1    10601
#
#     스크린수   상영횟수        코드                장르     러닝타임 제작국가  월별 제작국가구분
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
# !pip install chart_studio
# pandas에서 바로 plotly로 그래프를 제작해주는 라이브러리 
# !pip install cufflinks
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import cufflinks as cf
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()
# 코랩에서 plotly가 보이지 않을 때 설정
# 해결방법: default renderer 세팅을 바꿔주기 
# https://plotly.com/python/renderers/#setting-the-default-renderer

import plotly.io as pio
pio.renderers.default = 'colab'

# %%
fig_c = px.bar(movie, x ='연도_x', y='매출액', color='제작국가', title='연도별 총 매출액', height = 500, width=1200)
fig_c.update_xaxes(type='category')
fig_c.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
kr_fo = movie.groupby('제작국가구분').sum()
kr_fo
# Out:
#            연도_x     순위            매출액  매출액 점유율         관객수      상영횟수  \
# 제작국가구분
# 외국       894038  11726  7723055597401    674.1   980475560  24028916
# 한국      1018312  12499  9962315822624    840.1  1331089852  30803168
#
#                  코드    월별
# 제작국가구분
# 외국       8939757395  2875
# 한국      10180937969  3420

# %%
fig_c = px.bar(movie, x ='연도_x', y='매출액', color='제작국가구분', title='연도별 총 매출액', height = 500, width=1200)
fig_c.update_xaxes(type='category')
fig_c.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 한국 = 한국 
# 한국 + @ = 합동제작 
# 외국 + @ = 외국  

def set_values(x,value):
  return value[x]

dic = {'한국':'한국', '미국':'외국', '미국,영국':'외국', '중국':'외국', '영국':'외국', '일본':'외국', '한국,중국':'합동제작', '한국,네덜란드,홍콩':'합동제작',
       '프랑스':'외국', '한국,태국':'합동제작', '중국,한국,홍콩':'합동제작', '한국,중국,몽고':'합동제작', '한국,미국,호주':'합동제작', '미국,독일':'외국', '영국,미국':'외국',
       '인도':'외국', '미국,뉴질랜드':'외국', '한국,홍콩,일본,태국':'합동제작', '한국,미국,중국':'합동제작', '독일,미국,영국':'외국','한국,미국':'합동제작', '한국,일본,중국':'합동제작',
       '한국,미국,홍콩':'합동제작', '영국,호주':'외국', '한국,홍콩':'합동제작', '벨기에':'외국', '미국,캐나다':'외국', '한국,필리핀':'합동제작', '한국,체코':'합동제작', '한국,독일':'합동제작',
       '미국,호주':'외국', '미국,프랑스':'외국', '미국,영국,스페인':'외국', '미국,벨기에,영국':'외국', '미국,일본,프랑스,캐나다':'외국', '미국,호주,뉴질랜드':'외국', '기타':'외국',
       '대만':'외국'}

movie['제작국가구분'] = movie['제작국가'].apply(set_values, args=(dic,))

# %%
movie.groupby('제작국가구분').sum()
# Out:
#           연도_x     순위            매출액  매출액 점유율         관객수      상영횟수  \
# 제작국가구분
# 외국      894038  11726  7723055597401    674.1   980475560  24028916
# 한국      978093  11964  9472037421958    805.9  1264389996  29587619
# 합동제작     40219    535   490278400666     34.2    66699856   1215549
#
#                 코드    월별
# 제작국가구분
# 외국      8939757395  2875
# 한국      9779097416  3282
# 합동제작     401840553   138

# %%
fig_c = px.bar(movie, x ='연도_x', y='매출액', color='제작국가구분', title='연도별 총 매출액', height = 500, width=1200)
fig_c.update_xaxes(type='category')
fig_c.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
